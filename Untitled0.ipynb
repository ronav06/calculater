# %% [markdown]
# <a href="https://colab.research.google.com/github/ronav06/calculater/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name? ")
print("Hello, " + name + "!")
# Out:
# What is your name? ronav
# Hello, ronav!

# %%
'''
some text here
'''

# %% [markdown]
# text above  in ''' won't be exicuted as python dosn't allow when text is in ''' '''

# %% [markdown]
# **input** is used to display a question( "What is your name? ")

# %%
# this is a comment helps you understand a code

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **print** is used to show text

# %%
a = 4
print(a)

# %% [markdown]
# to add varibles you can do a = 5 (for example)
